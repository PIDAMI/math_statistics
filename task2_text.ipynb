# %% [markdown]
# Всегда работает закон больших чисел(если $\exists$ моменты больше 1), ЦПТ;
#
# коэф ассиметрии $\kappa_{3,n} = m_{3,n} / S_n^{3/2}$
#
# коэф эксцесса $\varepsilon = m_{4,n} / S_n^4$ \n

# %% [markdown]
# равномерное, стандартное норальное, пуассон, экспоненциальное, коши, n = 200
#
# 1) на отрезке [5,7] сгенерировать выборки, посчитать среднее, медиану, квартили 1/4 и 1/3, исправленную дисперсию, коэф ассиметрии и эксцесса, коэф вариации
#
# 2) N(17, 22) ($\eta = 17 + 22^{0.5} \xi$)
#
# 3) Пуассон(9)
#
# 4) экспоненциальное с парам 3
#
# 5) коши с парам (0, 2)
#
# Интервальные оценки: для N(4, 9) оценки среднего, дисперсии (точечные) и интервальные при $\alpha=0.05$ берем оценки для среднего и дисперсии
#
# потом гриппируем при k = 8, пределы - ближайшие целые числа; строим доверительные интервалы для того же гаусса. квартили
#
# Распределение стюдента $t_n = \xi_0 / (\chi_n^2 / n)^{0.5}$; быстро сходится к гауссу стандартному
# строим доверительные интервалы для стьюдента, полученного из группированного гаусса для среднего и дисперсии
#
# в тимс еще задание с оценками
